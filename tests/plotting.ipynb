# %%
from intervals.number import Interval as I
from intervals.methods import (lo,hi,mid,rad,width,intervalise, exp)
from intervals.random import uniform_endpoints 
from intervals.plotting import plot_intervals, plot_lower_bound
from intervals.mat_features import create_interval

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
x = np.arange(4)
y = np.arange(4)

# %%
y_i = create_interval(matrix=y, half_width=0.5)

# %%
y_i
# Out:
# [0.0,0.0]
# [0.5,1.5]
# [1.0,3.0]
# [1.5,4.5]

# %%
x[y_i.lo == y_i.hi]
# Out:
# array([0])

# %%
y_i[y_i.lo == y_i.hi].lo
# Out:
# array([0.])

# %%
fig, ax = plt.subplots()
ax.scatter(x[y_i.lo == y_i.hi], y_i[y_i.lo == y_i.hi].lo)

# %%
# plot a vector interval
plot_intervals(x, y_i)

# %%
# plot scaler interval
plot_intervals(x[2], y_i[2])

# %%
x[2]
# Out:
# 2

# %%
# x_test = np.array([[2]])
# len(x_test)
# x_test.shape
# # *x_test.shape == 1

# %%
# plot_intervals(x_test, y_i[2])

# %%
plot_lower_bound(x, y_i)
